# %%
# Import necessary libraries for data processing, model building, and visualization...
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.neural_network import MLPClassifier

import numpy as np
import os, cv2

# %%
# Function to plot images in a gallery format...
def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
  fig = plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
  plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
  for i in range(n_row * n_col):
    fig.add_subplot(n_row, n_col, i+1)
    plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
    plt.title(titles[i], size=12)
    plt.xticks(())
    plt.yticks(())
  plt.show()

# %%
# Define the directory containing face images...
dir_name = r"C:\Users\omi84\OneDrive\Desktop\Manthan\Project-FR\dataset\faces"

y = []
x = []
target_names = []
person_id = 0
h = w = 300
n_samples=0
class_names = []

# Loop through each person's directory and process their images...
for person_name in os.listdir(dir_name):
  dir_path = dir_name + "/" + person_name + "/"
  class_names.append(person_name)

  for img_name in os.listdir(dir_path):
    image_path = dir_path + img_name
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    resize_img = cv2.resize(gray, (h, w))
    v = resize_img.flatten()
    x.append(v)
    n_samples = n_samples+1
    y.append(person_id)
    target_names.append(person_name)
  person_id = person_id+1

# %%
# Convert data to numpy arrays for processing...
y = np.array(y)
x = np.array(x)
target_names = np.array(target_names)
n_features = x.shape[1]
print(y.shape,x.shape,target_names.shape)
print("Number of samples: ",n_samples)
# Out:
# (394,) (394, 90000) (394,)
# Number of samples:  394

# %%
# Split the data into training and testing sets...
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=25,random_state=42)

# Define the number of eigenfaces to extract...
n_components = 150
print("Extracting the top %d eigenfaces from %d faces" % (n_components, x_train.shape[0]))
# Out:
# Extracting the top 150 eigenfaces from 369 faces

# %%
# Apply PCA for dimensionality reduction...
pca = PCA(n_components=n_components,svd_solver = "randomized",whiten=True).fit(x_train)

# Get the eigenfaces...
eigenfaces = pca.components_.reshape((n_components, h, w))

# Generate titles for eigenfaces...
eigenfaces_titles = ["Eigenface %d" % i for i in range(n_components)]
plot_gallery(eigenfaces, eigenfaces_titles, h, w)
plt.show()

# Project the training and testing data onto the eigenfaces...
print("Projeceting the input data on the eigenfaces principle components")
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)
print(x_train_pca.shape,x_test_pca.shape)

# Apply LDA for further classification
lda = LDA()
lda.fit(x_train_pca,y_train)
x_train_lda = lda.transform(x_train_pca)
x_test_lda = lda.transform(x_test_pca)
print("Project done...")
# Out:
# Projeceting the input data on the eigenfaces principle components
# (369, 150) (25, 150)
# Project done...

# %%
# Train a multi-layer perceptron classifier...
clf = MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1000, verbose = True).fit(x_train_lda, y_train)
print("Model weight:")
model_info = [coef.shape for coef in clf.coefs_]
print(model_info)
# Out:
# Iteration 1, loss = 2.14848521
# Iteration 2, loss = 1.92127452
# Iteration 3, loss = 1.71518131
# Iteration 4, loss = 1.52909426
# Iteration 5, loss = 1.35689937
# Iteration 6, loss = 1.19771722
# Iteration 7, loss = 1.05040007
# Iteration 8, loss = 0.91593715
# Iteration 9, loss = 0.79543837
# Iteration 10, loss = 0.68909935
# Iteration 11, loss = 0.59590496
# Iteration 12, loss = 0.51475829
# Iteration 13, loss = 0.44572566
# Iteration 14, loss = 0.38846310
# Iteration 15, loss = 0.33975118
# Iteration 16, loss = 0.29964492
# Iteration 17, loss = 0.26521829
# Iteration 18, loss = 0.23639582
# Iteration 19, loss = 0.21253687
# Iteration 20, loss = 0.19250203
# Iteration 21, loss = 0.17544056
# Iteration 22, loss = 0.16139524
# Iteration 23, loss = 0.14908741
# Iteration 24, loss = 0.13836978
# Iteration 25, loss = 0.12921698
# Iteration 26, loss = 0.12134592
# Iteration 27, loss = 0.11430804
# Iteration 28, loss = 0.10825160
# Iteration 29, loss = 0.10280411
# Iteration 128, loss = 0.01507581
# Iteration 129, loss = 0.01491164
# Iteration 130, loss = 0.01467708
# Iteration 131, loss = 0.01449860
# Iteration 132, loss = 0.01431681
# Iteration 133, loss = 0.01413400
# Iteration 134, loss = 0.01397349
# Iteration 135, loss = 0.01381706
# Iteration 136, loss = 0.01367046
# Iteration 137, loss = 0.01346315
# Iteration 138, loss = 0.01327994
# Iteration 139, loss = 0.01311565
# Iteration 140, loss = 0.01298042
# Iteration 141, loss = 0.01281060
# Iteration 142, loss = 0.01265781
# Iteration 143, loss = 0.01249979
# Iteration 144, loss = 0.01236932
# Iteration 145, loss = 0.01216603
# Iteration 146, loss = 0.01206762
# Iteration 147, loss = 0.01187850
# Iteration 148, loss = 0.01176665
# Iteration 149, loss = 0.01162042
# Iteration 150, loss = 0.01150662
# Iteration 151, loss = 0.01134363
# Iteration 152, loss = 0.01120236
# Iteration 153, loss = 0.01111273
# Iteration 154, loss = 0.01095841
# Iteration 155, loss = 0.01082587
# Iteration 156, loss = 0.01070745
# Iteration 157, loss = 0.01056681
# Iteration 158, loss = 0.01048170
# Iteration 159, loss = 0.01034899
# Iteration 160, loss = 0.01022268
# Iteration 161, loss = 0.01008114
# Iteration 162, loss = 0.00997135
# Iteration 163, loss = 0.00985698
# Iteration 164, loss = 0.00974103
# Iteration 165, loss = 0.00962636
# Iteration 166, loss = 0.00952625
# Iteration 167, loss = 0.00944103
# Iteration 168, loss = 0.00929607
# Iteration 169, loss = 0.00916651
# Iteration 170, loss = 0.00906864
# Iteration 171, loss = 0.00899892
# Iteration 172, loss = 0.00886886
# Iteration 173, loss = 0.00877981
# Iteration 174, loss = 0.00870077
# Iteration 175, loss = 0.00857441
# Iteration 176, loss = 0.00849241
# Iteration 177, loss = 0.00836375
# Iteration 178, loss = 0.00828948
# Iteration 179, loss = 0.00818840
# Iteration 180, loss = 0.00810119
# Iteration 181, loss = 0.00801458
# Iteration 182, loss = 0.00792186
# Iteration 183, loss = 0.00783734
# Iteration 184, loss = 0.00775652
# Iteration 185, loss = 0.00766468
# Iteration 186, loss = 0.00759119
# Iteration 187, loss = 0.00753100
# Iteration 188, loss = 0.00745495
# Iteration 189, loss = 0.00733951
# Iteration 190, loss = 0.00726717
# Iteration 191, loss = 0.00717718
# Iteration 192, loss = 0.00709105
# Iteration 193, loss = 0.00701518
# Iteration 194, loss = 0.00694151
# Iteration 195, loss = 0.00686732
# Iteration 196, loss = 0.00678085
# Iteration 197, loss = 0.00672169
# Iteration 198, loss = 0.00666137
# Iteration 199, loss = 0.00657763
# Iteration 200, loss = 0.00650572
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Model weight:
# [(8, 100), (100, 100), (100, 9)]

# %%
# Predict classes for the test data...
y_pred = []
y_proba = []
for test_face in x_test_lda:
  prob = clf.predict_proba([test_face])[0]
  class_id = np.where(prob == np.max(prob))[0][0]
  y_pred.append(class_id)
  y_proba.append(np.max(prob))
y_pred = np.array(y_pred)

# Calculate accuracy and generate titles for the predicted results...
pred_titles = []
true_positive = 0
for i in range(y_pred.shape[0]):
  true_name = class_names[y_test[i]]
  pred_name = class_names[y_pred[i]]
  result = " Pred: %s \nPr: %s \nTrue: %s" % ( pred_name, str(y_proba[i])[0:3], true_name)
  pred_titles.append(result)
  if true_name == pred_name:
    true_positive = true_positive+1

# Print the accuracy...
print("Accuracy: ",true_positive*100/y_pred.shape[0])

# Plot the predicted results...
plot_gallery(x_test, pred_titles, h, w)
plt.show()
# Out:
# Accuracy:  88.0
